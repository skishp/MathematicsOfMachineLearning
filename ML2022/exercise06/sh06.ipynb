# %% [markdown]
# # Set up the notebook
#
# To begin, run the code in the next cell.
#
#  -  Begin by clicking inside the cell.
#  -  Click on the run button or simply press Shift + Enter on your keyboard to run the code.
#  -  If your code was run successfully you will see **Setup Complete.** as output below the cell.

# %%
# Set up the exercise

print ('Setup Complete.')
# Out:
# Setup Complete.

# %% [markdown]
# # Exercise 1
#
# Add a new cell / Code segment right here and print "Hello world!".

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# Now lets start our first machine learnig project.

# %%
# Importing all the required libraries

import numpy as np
import seaborn as sns
import sklearn
import sklearn.datasets
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
# Reading the Iris dataset
# The iris data set contains 50 samples from three species of Iris (setosa, virginica and versicolor) 
# and their sepal length, sepal width, petal length and petal width

iris=sklearn.datasets.load_iris()

# DESCR gives us a discription of the data set

print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
#Splitting the dataset into the training and testing set

X=iris.data
y=iris.target

x_train, x_test, y_train, y_test= train_test_split (X,y)

# %% [markdown]
# # Exercise 2:
# How many datapoints are in the training set and test set:

# %%
# Calculate the number of datapoints in the training set and test set here:
size_x_train = len(x_train)
size_x_test = len(x_test)

# %% [markdown]
# First, we should check that there are no missing values in the data set.
# But when we look at the description above, we see "Missing Attribute Values: None".
#
#
# ```
# # If there is data missing, one way is to replace the missing values by the mean
# # for example by using imputer
# # from sklearn.impute import SimpleImputer
# # imputer= SimpleImputer(add_indicator=True)
# # imputer.fit_transform(X)
# ```
#
# But again, we don't have missing data, so we can skip this step.

# %%
# Lets look at the features
# 
# sepal length: iris.data[:,0]
# sepal width: iris.data[:,1]
# petal length: iris.data[:,2]
# petal width: iris.data[:,3]

print(iris.data[:,0]) # prints an array containing the sepal length of each sample

# arrays in python start at 0!
# Out:
# [5.1 4.9 4.7 4.6 5.  5.4 4.6 5.  4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#  5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.
#  5.5 4.9 4.4 5.1 5.  4.5 4.4 5.  5.1 4.8 5.1 4.6 5.3 5.  7.  6.4 6.9 5.5
#  6.5 5.7 6.3 4.9 6.6 5.2 5.  5.9 6.  6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#  6.3 6.1 6.4 6.6 6.8 6.7 6.  5.7 5.5 5.5 5.8 6.  5.4 6.  6.7 6.3 5.6 5.5
#  5.5 6.1 5.8 5.  5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
#  6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.  6.9 5.6 7.7 6.3 6.7 7.2
#  6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.  6.9 6.7 6.9 5.8 6.8
#  6.7 6.7 6.3 6.5 6.2 5.9]

# %%
# With .target_names we can get all the classes
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# # Exercise 3
#
# Visualize the petal length and sepal length of the training set in a 2D plot: Plot the petal length on the x axis, the sepal length on the y axis and use colors for the classes.

# %%
# for visualization we use the library matplotlib.pyplot (which we already imported at the beginning when we wrote import matplotlib.pyplot as plt)

# use scatter plot

# add labels to the x and y axis
y_axis = x_train[:,0]
x_axis = x_train[:,2]

print(y_axis)

plt.scatter(x_axis, y_axis,c=y_train)
plt.xlabel("petal length")
plt.ylabel("sepal length")
# Out:
# [6.4 4.7 4.9 5.5 6.5 5.8 5.5 6.9 6.1 5.7 5.4 4.8 6.6 4.9 5.1 6.3 6.7 6.3
#  6.3 4.5 5.9 5.1 6.2 6.4 6.7 6.3 6.9 5.6 6.6 6.7 5.  4.9 7.7 6.7 4.6 5.8
#  5.2 7.2 6.1 7.7 4.7 6.1 4.6 5.4 5.8 7.6 4.8 5.  6.9 5.8 6.5 6.4 6.3 7.2
#  5.4 6.4 5.5 6.5 5.6 5.1 5.6 6.8 4.8 6.3 4.4 5.1 6.3 6.2 4.4 6.  6.2 6.
#  7.4 5.  5.7 6.8 7.  5.  6.7 4.6 6.  5.7 6.1 5.1 4.4 5.4 6.8 7.7 5.6 5.
#  6.3 5.2 7.3 5.5 5.  6.7 5.  5.8 6.  6.2 5.1 6.7 6.4 5.7 5.  5.5 7.2 6.5
#  5.8 5.7 6.7 7.7]
# Text(0, 0.5, 'sepal length')

# %% [markdown]
# # After visualizing the data, now lets move on to train a Decission Tree!

# %%
#Defining our model

model = tree.DecisionTreeClassifier()

# %%
# We already split the data set in a training set and test set at the beginning
# Now lets fit our model for the training set

model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Plotting our model in the form of a tree

plt.figure(figsize=(15,15))
tree.plot_tree(model)
plt.show()

# %%
y_pred = model.predict(x_train)

accuracy_score(y_train,y_pred)
# Out:
# 1.0

# %% [markdown]
# So the training error is 0, which is no surprise since we didn't bound the depth of the decission tree and it was trained until it perfectly matched the data.

# %%
#Predicting the value of the test data
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 2, 2, 0, 0, 0, 1, 0, 0, 2, 1, 2, 0, 0, 0, 1, 1, 1, 0, 0, 2, 1,
#        0, 2, 0, 2, 1, 1, 1, 2, 2, 1, 1, 0, 1, 0, 0, 0])

# %%
#Computing the accuracy of our model

accuracy_score(y_test,y_pred)
# Out:
# 0.9473684210526315

# %% [markdown]
# We would normally expect overfitting, since the decission tree is really complex compared to the data with four features, but our model performs well on the test data.

# %% [markdown]
# # Exercise 4
#
# Assume we lost the data regarding the sepal width and petal width.
#
# First, create a new data set containing only the sepal length, petal length and the class. Split the data set in training and test set. Train a decission tree on the training set. How is it's accuracy on the training set?

# %%
#since it was not specified how the the data looks
#we will be using np random to create data set
x_data_sepal = np.random.rand(1,1000)
x_data_sepal = x_data_sepal * 7

#rotate array
x_data_sepal = np.rot90(x_data_sepal)

x_data_petal  = np.random.rand(1,1000)
x_data_petal = x_data_petal*7

#rotate array
x_data_petal = np.rot90(x_data_petal)

#concatenate with axis=1 to get right data format 
x_data  = np.concatenate((x_data_sepal,x_data_petal), axis=1)

y_data  = np.array([np.random.randint(0,3,1000)])

#rotate data to match data format
y_data = np.rot90(y_data)

#splitting data set into train/test set
x_train, x_test, y_train, y_test = train_test_split(x_data,y_data)

#define model 
model = tree.DecisionTreeClassifier()

#train model 
model.fit(x_train,y_train)

#predict on train set
y_predict = model.predict(x_train)

#Training error is still 0, so accuracy score is 1
print(accuracy_score(y_train, y_predict))
# Out:
# 1.0
